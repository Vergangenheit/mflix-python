# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/screen_align.png" style="margin: 0 auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size=58px;">Bulk Writes</h1>

# %% [markdown]
# In this lesson we're going to discuss a different type of writes called "Bulk Writes," and the performance implications of these kinds of writes.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_many_writes.png" style="margin: 0 auto;">

# %% [markdown]
# Often times, our applications will encounter situations in which they need to perform a series of writes at once, and in some cases these writes have a causal effect on one another. One failing or succeeding in a group of operations, may affect your application logic.
#
# In this case, a user is purchasing food items on our grocery store application, and we are updating the database to reflect the new quantities we have in stock. This person bought 2 (point) apples, so we decrement the quantity by 2.
#
# When our application receives these writes, one option it has is to send each (point) of these writes (point) one at a time.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_first_update_one.png" style="margin: 0 auto;">

# %% [markdown]
# So the client sends a write (point) over to the database (point).

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_first_update_one_ack.png" style="margin: 0 auto;">

# %% [markdown]
# And at some point later, the client receives an acknowledgement that the write succeeded. Nice! Now let's send over the next write.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_second_update_one.png" style="margin: 0 auto;">

# %% [markdown]
# So we send over our next write,

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_second_update_one_ack.png" style="margin: 0 auto;">

# %% [markdown]
# And then eventually get our acknowledgement. Now we just performed two write operations, and it required two round trips to the database.
#
# That's a round trip to the database for each write operation - but if we already knew all the writes we wanted to perform, why is our client sending them each one at a time? You probably see where this is going.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_update_many_ordered.png" style="margin: 0 auto;">

# %% [markdown]
# So what we can do instead is "batch" these inserts together, and then send them in bulk. The exact method of grouping documents together is implemented differently in each driver, because the data structures are different, but the general idea is the same: Package a bunch of writes into a batch, usually a list or array (but again, the implementation is different in each language), and then send that whole batch to MongoDB.
#
# This is the implementation of bulk writes in the Mongo shell, and you can copy this from the lecture notes if you want to try it out. But it will look different in your chosen programming language, so bear that in mind.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_update_many_ordered_ack.png" style="margin: 0 auto;">

# %% [markdown]
# When a client sends a bulk write, it gets one acknowledgement back from the database for the whole batch.
#
# This is a benefit to our application's performance, because it limits the effect of latency on the overall speed of the operation. If it takes one second for each round trip, then sending one write at a time takes four seconds. But if we can send all four writes in one round trip, then sending four writes only takes one second.
#
# Now, the default behavior of a bulk write in Mongo is an ordered execution of these (point) writes (point). And in the ordered bulk write, any failure will stop execution of the rest of the batch. This benefits us in this case, because these (point) writes might have an effect on each other, like if two different update operations want to buy 4 sticks of butter, but there's only one stick left. In that situation, the first operation in the batch should get the last stick of butter, and the second operation should error out. That's why we need these (point) executed in order.
#
# The bulk write would throw an error on this (point) update statement, and then return an acknowledgement to the client **before** trying to purchase anymore (point) items. The acknowledgement (point) we get back will then tell us if something errored out.

# %% [markdown]
# ### Ordered Bulk Write
#
# - The default setting for bulk writes in MongoDB
# - Executes writes sequentially
#     - Will end execution after first write failure

# %% [markdown]
# By default, bulk writes in Mongo will be ordered. This means that even though we send all the writes at the same time, the replica (point) set will apply them in the order they were sent.
#
# Sending an ordered bulk write implies that each write (point to butter or eggs) in the batch depends on all the writes (point to the ones above it) that occurred before it. So if a write operation results in an error, all subsequent writes will not be executed, because Mongo assumes that those (point to ones below it) writes were expecting this (point) write to succeed.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_update_many_unordered.png"/>

# %% [markdown]
# But there's also a chance that the writes in our batch are not dependent on each other. In this case, we've just received a shipment of food to the warehouse, and we want to update the new food quantities in stock.
#
# Because all these (point) changes are additive, we don't need all of them to be executed in order, because they're not causally related. So I passed this "ordered: false" flag to the bulk write command, which will execute them in parallel. If some of them fail (for whatever reason), we can still continue on with the execution of other operations in the batch.

# %% [markdown]
# <img src="https://s3.amazonaws.com/edu-static.mongodb.com/lessons/M220/notebook_assets/replica_set_update_many_unordered_ack.png"/>

# %% [markdown]
# And when we receive an acknowledgement back from the database, it will let us know if any operations failed.

# %% [markdown]
# ### Unordered Bulk Write
#
# - Has to be specified with the flag: `{ ordered: false }`
# - Executes writes in parallel

# %% [markdown]
# If the writes in our batch don't have any causal relationship, then the client can send them over in an "Unordered Bulk Write". This will execute the write operations in parallel, so the writes are non-blocking. And as a result, a single failure won't prevent any of the other writes from succeeding. Now those writes might fail on their own, but their execution is not tied to the success of any other writes.

# %% [markdown]
# ## Summary
#
# - Bulk writes allow database clients to send multiple writes
# - Can either be ordered or unordered

# %% [markdown]
# So in conclusion, bulk writes make it more efficient to insert many documents into the database, by sending them all at the same time.
#
# These bulk writes can be ordered, which means writes are executed in the order they were sent to the database, and any errors will prevent subsequent writes from executing.
#
# They can also be unordered, which means writes are executed in parallel, and errors don't affect the execution of other writes.
#
# One small thing to note: in a sharded collection, ordered bulk writes are expected to take longer because different write operations need to be routed to their designated shards. An ordered bulk write might reach the mongos in one batch, but then it has to be serialized across the different shards. Regardless of their designated shard, the write operation needs to be evaluated to see if we should continue or exit the execution of the remainder of the batch.

# %%
import pymongo
from bson.json_util import dumps
from typing import Union, Optional, List, Dict
from pymongo.collection import Collection
from pymongo.command_cursor import CommandCursor
from bson.objectid import ObjectId
import datetime
from pymongo.cursor import Cursor
from pymongo.results import UpdateResult, InsertOneResult, DeleteResult

uri = "mongodb+srv://m220student:m220password@mflix.hqydc.mongodb.net/test"
client = pymongo.MongoClient(uri)
mflix = client.sample_mflix
movies = mflix.movies

# %%
predicate = {"$and": [{"lastupdated": {"$exists": True}}, {"lastupdated": {"$type": "string"}}]}
projection = {"_id": 1, "lastupdated": 2}

# %%
cursor: Cursor = movies.find(predicate, projection)

# %%
list(cursor)
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd4eaf'),
#   'lastupdated': '2015-09-15 02:07:14.247000000'},
#  {'_id': ObjectId('573a1391f29313caabcd6e2a'),
#   'lastupdated': '2015-05-07 01:07:01.633000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5b9a'),
#   'lastupdated': '2015-08-16 01:13:00.090000000'},
#  {'_id': ObjectId('573a1390f29313caabcd6377'),
#   'lastupdated': '2015-06-05 00:40:35.137000000'},
#  {'_id': ObjectId('573a1391f29313caabcd6f98'),
#   'lastupdated': '2015-07-20 00:01:29.560000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7850'),
#   'lastupdated': '2015-09-03 00:43:12.727000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7db6'),
#   'lastupdated': '2015-05-10 00:19:38.277000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8acf'),
#   'lastupdated': '2015-07-04 00:36:23.880000000'},
#  {'_id': ObjectId('573a1391f29313caabcd93a3'),
#   'lastupdated': '2015-08-31 00:25:42.873000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9950'),
#   'lastupdated': '2015-08-21 00:02:36.330000000'},
#  {'_id': ObjectId('573a1391f29313caabcd796e'),
#   'lastupdated': '2015-08-21 00:59:44.877000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7a34'),
#   'lastupdated': '2015-09-02 00:22:09.303000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7da6'),
#   'lastupdated': '2015-08-13 00:31:55.567000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7faa'),
#   'lastupdated': '2015-08-22 00:15:14.157000000'},
#  {'_id': ObjectId('573a1391f29313caabcd883d'),
#   'lastupdated': '2015-08-21 00:07:08.593000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8ae8'),
#   'lastupdated': '2015-08-19 00:41:24.220000000'},
#  {'_id': ObjectId('573a1391f29313caabcd944c'),
#   'lastupdated': '2015-08-08 00:38:18.023000000'},
#  {'_id': ObjectId('573a1392f29313caabcd97a7'),
#   'lastupdated': '2015-09-03 00:52:22.460000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9aff'),
#   'lastupdated': '2015-09-15 03:22:11.277000000'},
#  {'_id': ObjectId('573a1390f29313caabcd446f'),
#   'lastupdated': '2015-08-13 00:46:30.660000000'},
#  {'_id': ObjectId('573a1390f29313caabcd4323'),
#   'lastupdated': '2015-08-29 00:27:45.437000000'},
#  {'_id': ObjectId('573a1391f29313caabcd6ea2'),
#   'lastupdated': '2015-06-20 00:38:08.303000000'},
#  {'_id': ObjectId('573a1391f29313caabcd70b4'),
#   'lastupdated': '2015-08-24 00:59:30.430000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8319'),
#   'lastupdated': '2015-08-19 00:35:01.953000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8c57'),
#   'lastupdated': '2015-09-12 00:19:10.117000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8dd1'),
#   'lastupdated': '2015-06-05 00:25:03.927000000'},
#  {'_id': ObjectId('573a1391f29313caabcd93aa'),
#   'lastupdated': '2015-08-12 00:08:59.097000000'},
#  {'_id': ObjectId('573a1391f29313caabcd95ee'),
#   'lastupdated': '2015-08-10 00:07:16.517000000'},
#  {'_id': ObjectId('573a1392f29313caabcd99e3'),
#   'lastupdated': '2015-08-19 00:33:29.483000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7ac4'),
#   'lastupdated': '2015-08-25 00:59:36.103000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7f08'),
#   'lastupdated': '2015-08-14 00:31:35.990000000'},
#  {'_id': ObjectId('573a1391f29313caabcd820b'),
#   'lastupdated': '2015-08-25 00:40:54.383000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8675'),
#   'lastupdated': '2015-08-12 00:52:46.173000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8e8f'),
#   'lastupdated': '2015-07-21 08:18:53.010000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9269'),
#   'lastupdated': '2015-06-12 10:10:41.833000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9458'),
#   'lastupdated': '2015-09-16 13:13:05.537000000'},
#  {'_id': ObjectId('573a1392f29313caabcd975d'),
#   'lastupdated': '2015-09-16 13:01:17.997000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9a3b'),
#   'lastupdated': '2015-08-21 00:15:38.343000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5c0f'),
#   'lastupdated': '2015-09-05 00:01:19.580000000'},
#  {'_id': ObjectId('573a1391f29313caabcd71e3'),
#   'lastupdated': '2015-08-21 00:15:46.140000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8792'),
#   'lastupdated': '2015-08-21 00:02:19.313000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8de7'),
#   'lastupdated': '2015-09-02 00:32:43.523000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9053'),
#   'lastupdated': '2015-07-26 00:19:30.210000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9258'),
#   'lastupdated': '2015-01-17 00:46:41'},
#  {'_id': ObjectId('573a1391f29313caabcd9336'),
#   'lastupdated': '2015-08-05 00:31:58.913000000'},
#  {'_id': ObjectId('573a1391f29313caabcd962d'),
#   'lastupdated': '2015-08-20 01:04:57.593000000'},
#  {'_id': ObjectId('573a1392f29313caabcd99a3'),
#   'lastupdated': '2015-08-03 01:02:12.350000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9a76'),
#   'lastupdated': '2015-09-05 00:24:21.237000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5501'),
#   'lastupdated': '2015-08-31 00:41:20.670000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7e23'),
#   'lastupdated': '2015-08-12 00:47:35.017000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7fb7'),
#   'lastupdated': '2015-08-26 00:55:12.337000000'},
#  {'_id': ObjectId('573a1391f29313caabcd821b'),
#   'lastupdated': '2015-09-15 03:21:41.617000000'},
#  {'_id': ObjectId('573a1391f29313caabcd82da'),
#   'lastupdated': '2015-09-02 00:38:57.710000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8543'),
#   'lastupdated': '2015-08-22 00:10:17.500000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8a5b'),
#   'lastupdated': '2015-09-05 00:01:12.580000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8ba2'),
#   'lastupdated': '2015-09-11 00:00:30.930000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8e90'),
#   'lastupdated': '2015-08-25 00:13:46.273000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8f66'),
#   'lastupdated': '2015-09-02 00:29:37.070000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9651'),
#   'lastupdated': '2015-08-27 00:16:10.930000000'},
#  {'_id': ObjectId('573a1391f29313caabcd96ae'),
#   'lastupdated': '2015-09-06 00:10:44.853000000'},
#  {'_id': ObjectId('573a1392f29313caabcd987c'),
#   'lastupdated': '2015-07-13 00:05:22.090000000'},
#  {'_id': ObjectId('573a1390f29313caabcd4135'),
#   'lastupdated': '2015-08-26 00:03:50.133000000'},
#  {'_id': ObjectId('573a1390f29313caabcd50e5'),
#   'lastupdated': '2015-08-18 01:03:15.313000000'},
#  {'_id': ObjectId('573a1390f29313caabcd548c'),
#   'lastupdated': '2015-09-11 00:32:27.763000000'},
#  {'_id': ObjectId('573a1390f29313caabcd680a'),
#   'lastupdated': '2015-08-21 00:06:48.907000000'},
#  {'_id': ObjectId('573a1391f29313caabcd89aa'),
#   'lastupdated': '2015-09-02 00:36:34.413000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8d7b'),
#   'lastupdated': '2015-05-22 01:54:12.097000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8d96'),
#   'lastupdated': '2015-07-12 00:48:42.467000000'},
#  {'_id': ObjectId('573a1391f29313caabcd91b4'),
#   'lastupdated': '2015-08-15 00:10:14.427000000'},
#  {'_id': ObjectId('573a1391f29313caabcd94b1'),
#   'lastupdated': '2015-09-02 00:25:04.023000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9552'),
#   'lastupdated': '2015-08-27 00:28:07.760000000'},
#  {'_id': ObjectId('573a1391f29313caabcd956e'),
#   'lastupdated': '2015-09-07 07:20:20.853000000'},
#  {'_id': ObjectId('573a1392f29313caabcd97ee'),
#   'lastupdated': '2015-07-23 00:01:26.507000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9a10'),
#   'lastupdated': '2015-08-25 00:03:34.743000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9a7e'),
#   'lastupdated': '2015-09-15 01:36:35.213000000'},
#  {'_id': ObjectId('573a1391f29313caabcd6d40'),
#   'lastupdated': '2015-08-11 00:35:33.717000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7915'),
#   'lastupdated': '2015-08-11 00:02:19.313000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7bc3'),
#   'lastupdated': '2015-09-02 00:21:48.663000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7c9e'),
#   'lastupdated': '2015-08-09 01:05:18.003000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7d4e'),
#   'lastupdated': '2015-09-02 00:26:21.820000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7e6e'),
#   'lastupdated': '2015-04-17 00:50:41.207000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7f27'),
#   'lastupdated': '2015-09-07 01:05:56.673000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8b94'),
#   'lastupdated': '2015-08-30 00:27:52.727000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9871'),
#   'lastupdated': '2015-07-08 09:06:09.550000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5293'),
#   'lastupdated': '2015-09-12 00:01:18.647000000'},
#  {'_id': ObjectId('573a1391f29313caabcd715c'),
#   'lastupdated': '2015-09-05 00:24:11.143000000'},
#  {'_id': ObjectId('573a1390f29313caabcd42e8'),
#   'lastupdated': '2015-08-13 00:27:59.177000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7626'),
#   'lastupdated': '2015-08-11 00:29:16.047000000'},
#  {'_id': ObjectId('573a1391f29313caabcd80db'),
#   'lastupdated': '2015-09-05 00:01:09.893000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8cf4'),
#   'lastupdated': '2015-08-28 00:19:58.017000000'},
#  {'_id': ObjectId('573a1391f29313caabcd91d7'),
#   'lastupdated': '2015-07-20 00:26:02.200000000'},
#  {'_id': ObjectId('573a1391f29313caabcd935e'),
#   'lastupdated': '2015-09-05 00:00:20.783000000'},
#  {'_id': ObjectId('573a1391f29313caabcd95f6'),
#   'lastupdated': '2015-08-21 00:50:48.813000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9721'),
#   'lastupdated': '2015-03-02 00:19:30.347000000'},
#  {'_id': ObjectId('573a1390f29313caabcd56df'),
#   'lastupdated': '2015-07-27 00:07:43.230000000'},
#  {'_id': ObjectId('573a1390f29313caabcd63d6'),
#   'lastupdated': '2015-07-20 00:32:04.810000000'},
#  {'_id': ObjectId('573a1391f29313caabcd6d90'),
#   'lastupdated': '2015-07-19 00:12:27.010000000'},
#  {'_id': ObjectId('573a1391f29313caabcd75b5'),
#   'lastupdated': '2015-08-21 00:04:53.453000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7616'),
#   'lastupdated': '2015-04-26 00:03:19.913000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7c4c'),
#   'lastupdated': '2015-08-11 00:02:35.483000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8210'),
#   'lastupdated': '2015-08-22 01:05:18.360000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8521'),
#   'lastupdated': '2015-08-28 00:55:59.283000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8c6b'),
#   'lastupdated': '2015-08-21 00:53:36.437000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8cef'),
#   'lastupdated': '2015-07-31 00:49:13.677000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8e45'),
#   'lastupdated': '2015-09-11 00:24:40.773000000'},
#  {'_id': ObjectId('573a1391f29313caabcd91dc'),
#   'lastupdated': '2015-09-17 03:52:20.697000000'},
#  {'_id': ObjectId('573a1391f29313caabcd952a'),
#   'lastupdated': '2015-06-20 00:30:43.697000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9637'),
#   'lastupdated': '2015-08-28 00:30:04.660000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9aab'),
#   'lastupdated': '2015-08-24 00:02:32.743000000'},
#  {'_id': ObjectId('573a1390f29313caabcd516c'),
#   'lastupdated': '2015-09-16 12:11:37.770000000'},
#  {'_id': ObjectId('573a1390f29313caabcd587d'),
#   'lastupdated': '2015-08-14 01:28:18.957000000'},
#  {'_id': ObjectId('573a1391f29313caabcd71f5'),
#   'lastupdated': '2015-06-25 00:02:16.613000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7f11'),
#   'lastupdated': '2015-08-29 00:37:14.843000000'},
#  {'_id': ObjectId('573a1391f29313caabcd95fb'),
#   'lastupdated': '2015-08-01 00:55:50.453000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9688'),
#   'lastupdated': '2015-08-22 01:03:07.327000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5a93'),
#   'lastupdated': '2015-04-30 02:13:27.863000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7f19'),
#   'lastupdated': '2015-09-05 00:00:55.113000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8414'),
#   'lastupdated': '2015-09-04 00:09:30.553000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8aad'),
#   'lastupdated': '2015-08-25 00:14:11.633000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9596'),
#   'lastupdated': '2015-09-17 02:00:48.850000000'},
#  {'_id': ObjectId('573a1392f29313caabcd98c3'),
#   'lastupdated': '2015-08-18 00:11:52.283000000'},
#  {'_id': ObjectId('573a1390f29313caabcd60e4'),
#   'lastupdated': '2015-09-17 04:52:02.293000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5ea4'),
#   'lastupdated': '2015-09-07 00:51:32.560000000'},
#  {'_id': ObjectId('573a1391f29313caabcd79e4'),
#   'lastupdated': '2015-08-05 01:02:46.273000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7e30'),
#   'lastupdated': '2015-08-18 00:22:19.750000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7f07'),
#   'lastupdated': '2015-08-19 00:30:51.783000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8780'),
#   'lastupdated': '2015-08-06 00:01:15.977000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8a75'),
#   'lastupdated': '2015-09-16 12:49:42.070000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8a82'),
#   'lastupdated': '2015-08-08 00:30:05.023000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9600'),
#   'lastupdated': '2015-09-06 00:10:05.493000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9a5d'),
#   'lastupdated': '2015-08-30 00:01:29.900000000'},
#  {'_id': ObjectId('573a1390f29313caabcd5967'),
#   'lastupdated': '2015-09-02 00:24:27.333000000'},
#  {'_id': ObjectId('573a1390f29313caabcd6223'),
#   'lastupdated': '2015-07-27 00:11:31.387000000'},
#  {'_id': ObjectId('573a1391f29313caabcd72f0'),
#   'lastupdated': '2015-08-23 01:12:08.943000000'},
#  {'_id': ObjectId('573a1391f29313caabcd73f4'),
#   'lastupdated': '2015-09-16 06:21:19.243000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7b98'),
#   'lastupdated': '2015-09-11 00:00:29.303000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8268'),
#   'lastupdated': '2015-08-22 01:10:11.970000000'},
#  {'_id': ObjectId('573a1391f29313caabcd88d8'),
#   'lastupdated': '2015-08-24 01:16:23.650000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8945'),
#   'lastupdated': '2015-09-12 00:26:13.493000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8978'),
#   'lastupdated': '2015-08-26 00:11:36.870000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8979'),
#   'lastupdated': '2015-06-20 00:36:05.633000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8e26'),
#   'lastupdated': '2015-09-10 17:11:03.607000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8f04'),
#   'lastupdated': '2015-09-17 04:51:54.903000000'},
#  {'_id': ObjectId('573a1391f29313caabcd68d0'),
#   'lastupdated': '2015-04-17 00:16:14.220000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7d02'),
#   'lastupdated': '2015-08-28 00:37:15.970000000'},
#  {'_id': ObjectId('573a1391f29313caabcd806b'),
#   'lastupdated': '2015-09-10 17:23:59.913000000'},
#  {'_id': ObjectId('573a1391f29313caabcd830e'),
#   'lastupdated': '2015-08-03 00:05:32.240000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8713'),
#   'lastupdated': '2015-09-15 02:11:47.513000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8a4c'),
#   'lastupdated': '2015-08-11 00:02:10.063000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8bb2'),
#   'lastupdated': '2015-09-02 00:39:15.460000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8cbd'),
#   'lastupdated': '2015-08-15 00:05:25.037000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8ce8'),
#   'lastupdated': '2015-09-07 01:03:31.287000000'},
#  {'_id': ObjectId('573a1391f29313caabcd967e'),
#   'lastupdated': '2015-08-29 00:54:29'},
#  {'_id': ObjectId('573a1390f29313caabcd4803'),
#   'lastupdated': '2015-08-29 01:09:03.030000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7472'),
#   'lastupdated': '2015-09-05 00:00:37.817000000'},
#  {'_id': ObjectId('573a1391f29313caabcd7586'),
#   'lastupdated': '2015-08-29 00:27:40.327000000'},
#  {'_id': ObjectId('573a1391f29313caabcd8783'),
#   'lastupdated': '2015-09-17 04:44:02.223000000'},
#  {'_id': ObjectId('573a1391f29313caabcd9264'),
#   'lastupdated': '2015-08-25 00:14:05.103000000'},
#  {'_id': ObjectId('573a1391f29313caabcd96ac'),
#   'lastupdated': '2015-08-21 01:03:33.500000000'},
#  {'_id': ObjectId('573a1392f29313caabcd980d'),
#   'lastupdated': '2015-09-10 17:05:22.627000000'},
#  {'_id': ObjectId('573a1392f29313caabcda16f'),
#   'lastupdated': '2015-09-17 04:39:42.840000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9b68'),
#   'lastupdated': '2015-03-25 00:21:00.090000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9bf5'),
#   'lastupdated': '2015-06-27 00:39:50.077000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9d4c'),
#   'lastupdated': '2015-09-17 01:50:05.933000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9e3e'),
#   'lastupdated': '2015-09-07 01:16:07.067000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9c5d'),
#   'lastupdated': '2015-07-13 00:10:45.307000000'},
#  {'_id': ObjectId('573a1392f29313caabcda34f'),
#   'lastupdated': '2015-09-10 17:20:13.227000000'},
#  {'_id': ObjectId('573a1392f29313caabcda482'),
#   'lastupdated': '2015-08-10 01:02:32.690000000'},
#  {'_id': ObjectId('573a1392f29313caabcda98f'),
#   'lastupdated': '2015-09-17 04:39:53.683000000'},
#  {'_id': ObjectId('573a1392f29313caabcdab08'),
#   'lastupdated': '2015-05-25 00:40:15.450000000'},
#  {'_id': ObjectId('573a1392f29313caabcdac95'),
#   'lastupdated': '2015-08-28 00:35:14.627000000'},
#  {'_id': ObjectId('573a1392f29313caabcdae43'),
#   'lastupdated': '2015-07-26 00:02:41.990000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9b93'),
#   'lastupdated': '2015-08-16 00:10:30.883000000'},
#  {'_id': ObjectId('573a1392f29313caabcda126'),
#   'lastupdated': '2015-08-23 01:12:02.303000000'},
#  {'_id': ObjectId('573a1392f29313caabcda224'),
#   'lastupdated': '2015-08-31 00:05:15.920000000'},
#  {'_id': ObjectId('573a1392f29313caabcda2c7'),
#   'lastupdated': '2015-08-05 00:03:37.803000000'},
#  {'_id': ObjectId('573a1392f29313caabcda3ce'),
#   'lastupdated': '2015-08-22 00:06:38.750000000'},
#  {'_id': ObjectId('573a1392f29313caabcda451'),
#   'lastupdated': '2015-08-12 00:13:12.470000000'},
#  {'_id': ObjectId('573a1392f29313caabcda594'),
#   'lastupdated': '2015-09-15 03:21:37.103000000'},
#  {'_id': ObjectId('573a1392f29313caabcda826'),
#   'lastupdated': '2015-09-02 00:36:23.240000000'},
#  {'_id': ObjectId('573a1392f29313caabcda82b'),
#   'lastupdated': '2015-08-28 00:38:24.097000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaae8'),
#   'lastupdated': '2015-08-29 00:52:27.797000000'},
#  {'_id': ObjectId('573a1392f29313caabcdab4a'),
#   'lastupdated': '2015-05-12 00:22:56.013000000'},
#  {'_id': ObjectId('573a1392f29313caabcdab98'),
#   'lastupdated': '2015-09-17 04:41:19.333000000'},
#  {'_id': ObjectId('573a1392f29313caabcdabd3'),
#   'lastupdated': '2015-08-17 00:06:53.547000000'},
#  {'_id': ObjectId('573a1392f29313caabcdad30'),
#   'lastupdated': '2015-08-30 00:13:37.197000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf8c'),
#   'lastupdated': '2015-06-17 19:13:08.717000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9bf8'),
#   'lastupdated': '2015-08-18 00:27:13.017000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6e1'),
#   'lastupdated': '2015-09-05 00:25:26.877000000'},
#  {'_id': ObjectId('573a1392f29313caabcda964'),
#   'lastupdated': '2015-08-13 00:20:37.803000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaa70'),
#   'lastupdated': '2015-05-30 00:43:45.590000000'},
#  {'_id': ObjectId('573a1392f29313caabcdabc6'),
#   'lastupdated': '2015-08-04 00:08:08.460000000'},
#  {'_id': ObjectId('573a1392f29313caabcdacf0'),
#   'lastupdated': '2015-09-14 12:56:01.370000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb18d'),
#   'lastupdated': '2015-08-11 00:18:31.687000000'},
#  {'_id': ObjectId('573a1392f29313caabcda515'),
#   'lastupdated': '2015-08-27 00:05:48.713000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9d4f'),
#   'lastupdated': '2015-08-20 01:02:13.173000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9f09'),
#   'lastupdated': '2015-09-15 03:21:37.663000000'},
#  {'_id': ObjectId('573a1392f29313caabcda262'),
#   'lastupdated': '2015-09-02 00:26:34.287000000'},
#  {'_id': ObjectId('573a1392f29313caabcda473'),
#   'lastupdated': '2015-06-15 00:12:16.517000000'},
#  {'_id': ObjectId('573a1392f29313caabcda4b0'),
#   'lastupdated': '2015-05-27 00:04:40.333000000'},
#  {'_id': ObjectId('573a1392f29313caabcda79a'),
#   'lastupdated': '2015-08-20 00:41:38.923000000'},
#  {'_id': ObjectId('573a1392f29313caabcda9a8'),
#   'lastupdated': '2015-04-14 00:24:39.827000000'},
#  {'_id': ObjectId('573a1392f29313caabcdac43'),
#   'lastupdated': '2015-08-24 01:01:28.400000000'},
#  {'_id': ObjectId('573a1392f29313caabcdadb7'),
#   'lastupdated': '2015-08-02 00:21:57.217000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9ed7'),
#   'lastupdated': '2015-08-21 00:17:16.453000000'},
#  {'_id': ObjectId('573a1392f29313caabcda792'),
#   'lastupdated': '2015-08-25 00:03:52.620000000'},
#  {'_id': ObjectId('573a1392f29313caabcda896'),
#   'lastupdated': '2015-08-25 00:41:32.167000000'},
#  {'_id': ObjectId('573a1392f29313caabcda974'),
#   'lastupdated': '2015-08-21 00:15:41.563000000'},
#  {'_id': ObjectId('573a1392f29313caabcdac22'),
#   'lastupdated': '2015-08-20 00:35:09.343000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf75'),
#   'lastupdated': '2015-08-28 00:36:27.707000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9fc4'),
#   'lastupdated': '2015-09-05 00:24:47.660000000'},
#  {'_id': ObjectId('573a1392f29313caabcda2a4'),
#   'lastupdated': '2015-08-21 01:05:17.110000000'},
#  {'_id': ObjectId('573a1392f29313caabcda4a9'),
#   'lastupdated': '2015-08-23 01:13:16.613000000'},
#  {'_id': ObjectId('573a1392f29313caabcda636'),
#   'lastupdated': '2015-08-20 01:13:03.983000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6b3'),
#   'lastupdated': '2015-08-14 01:32:52.380000000'},
#  {'_id': ObjectId('573a1392f29313caabcda713'),
#   'lastupdated': '2015-08-26 00:25:21.213000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaa59'),
#   'lastupdated': '2015-09-17 04:41:45.343000000'},
#  {'_id': ObjectId('573a1392f29313caabcdab28'),
#   'lastupdated': '2015-08-11 00:30:16.593000000'},
#  {'_id': ObjectId('573a1392f29313caabcdae4f'),
#   'lastupdated': '2015-09-14 10:39:03.470000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaef9'),
#   'lastupdated': '2015-09-05 00:26:10.347000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf17'),
#   'lastupdated': '2015-06-05 00:34:46.883000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb0bd'),
#   'lastupdated': '2015-09-05 00:01:09.893000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6f1'),
#   'lastupdated': '2015-08-05 00:51:48.930000000'},
#  {'_id': ObjectId('573a1392f29313caabcda722'),
#   'lastupdated': '2015-09-10 17:41:49.093000000'},
#  {'_id': ObjectId('573a1392f29313caabcda755'),
#   'lastupdated': '2015-09-11 00:37:56.387000000'},
#  {'_id': ObjectId('573a1392f29313caabcda998'),
#   'lastupdated': '2015-09-17 02:11:55.840000000'},
#  {'_id': ObjectId('573a1392f29313caabcdad0d'),
#   'lastupdated': '2015-07-15 00:37:53.257000000'},
#  {'_id': ObjectId('573a1392f29313caabcdafca'),
#   'lastupdated': '2015-08-16 00:27:18.243000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb012'),
#   'lastupdated': '2015-08-21 00:02:41.937000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9be6'),
#   'lastupdated': '2015-08-31 00:24:56.293000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9bcf'),
#   'lastupdated': '2015-08-12 01:00:14.097000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9ee9'),
#   'lastupdated': '2015-08-24 00:11:28.103000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9dee'),
#   'lastupdated': '2015-08-18 00:59:15.453000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9f92'),
#   'lastupdated': '2015-08-19 00:24:32.983000000'},
#  {'_id': ObjectId('573a1392f29313caabcda0e7'),
#   'lastupdated': '2015-08-21 00:10:57.657000000'},
#  {'_id': ObjectId('573a1392f29313caabcda27e'),
#   'lastupdated': '2015-08-25 00:01:39.180000000'},
#  {'_id': ObjectId('573a1392f29313caabcda2c5'),
#   'lastupdated': '2015-07-25 00:22:28.740000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6f4'),
#   'lastupdated': '2015-08-29 00:55:22.780000000'},
#  {'_id': ObjectId('573a1392f29313caabcdabdd'),
#   'lastupdated': '2015-09-17 04:39:07.407000000'},
#  {'_id': ObjectId('573a1392f29313caabcdad3c'),
#   'lastupdated': '2015-08-05 01:10:58.600000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb155'),
#   'lastupdated': '2015-07-04 00:05:16.370000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9d4a'),
#   'lastupdated': '2015-09-04 00:30:22.147000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9c4c'),
#   'lastupdated': '2015-06-03 00:02:33.337000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9e7c'),
#   'lastupdated': '2015-09-02 00:29:47.477000000'},
#  {'_id': ObjectId('573a1392f29313caabcda111'),
#   'lastupdated': '2015-09-16 11:04:54.197000000'},
#  {'_id': ObjectId('573a1392f29313caabcda162'),
#   'lastupdated': '2015-09-03 01:13:55.240000000'},
#  {'_id': ObjectId('573a1392f29313caabcda206'),
#   'lastupdated': '2015-08-21 00:19:04.407000000'},
#  {'_id': ObjectId('573a1392f29313caabcda241'),
#   'lastupdated': '2015-09-15 03:21:38.007000000'},
#  {'_id': ObjectId('573a1392f29313caabcda5fe'),
#   'lastupdated': '2015-08-30 00:46:08.960000000'},
#  {'_id': ObjectId('573a1392f29313caabcda619'),
#   'lastupdated': '2015-08-23 00:16:46.687000000'},
#  {'_id': ObjectId('573a1392f29313caabcda63c'),
#   'lastupdated': '2015-08-31 00:25:27.623000000'},
#  {'_id': ObjectId('573a1392f29313caabcda653'),
#   'lastupdated': '2015-07-25 00:02:46.790000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6aa'),
#   'lastupdated': '2015-07-03 00:00:08.083000000'},
#  {'_id': ObjectId('573a1392f29313caabcda7a1'),
#   'lastupdated': '2015-08-25 00:05:49.290000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaab4'),
#   'lastupdated': '2015-08-04 00:08:31.773000000'},
#  {'_id': ObjectId('573a1392f29313caabcdae1e'),
#   'lastupdated': '2015-09-05 00:26:05.893000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf28'),
#   'lastupdated': '2015-08-20 01:03:44.640000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9c1b'),
#   'lastupdated': '2015-06-24 00:22:17.033000000'},
#  {'_id': ObjectId('573a1392f29313caabcda2a2'),
#   'lastupdated': '2015-08-21 00:55:18.283000000'},
#  {'_id': ObjectId('573a1392f29313caabcda43a'),
#   'lastupdated': '2015-08-13 00:30:52.397000000'},
#  {'_id': ObjectId('573a1392f29313caabcda641'),
#   'lastupdated': '2015-08-03 00:52:53.507000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf1c'),
#   'lastupdated': '2015-08-21 00:04:03.127000000'},
#  {'_id': ObjectId('573a1392f29313caabcdafe6'),
#   'lastupdated': '2015-09-17 04:40:58.787000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb18f'),
#   'lastupdated': '2015-07-26 00:41:02.490000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9df7'),
#   'lastupdated': '2015-09-07 00:40:27.640000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9cce'),
#   'lastupdated': '2015-04-19 00:49:42.517000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9e9b'),
#   'lastupdated': '2015-08-22 01:09:10.093000000'},
#  {'_id': ObjectId('573a1392f29313caabcda0a5'),
#   'lastupdated': '2015-09-10 17:40:59.153000000'},
#  {'_id': ObjectId('573a1392f29313caabcda81f'),
#   'lastupdated': '2015-06-29 01:16:30.963000000'},
#  {'_id': ObjectId('573a1392f29313caabcda8c3'),
#   'lastupdated': '2015-08-26 01:14:49.383000000'},
#  {'_id': ObjectId('573a1392f29313caabcdace2'),
#   'lastupdated': '2015-08-16 00:49:12.603000000'},
#  {'_id': ObjectId('573a1392f29313caabcdae3d'),
#   'lastupdated': '2015-09-04 00:06:38.867000000'},
#  {'_id': ObjectId('573a1392f29313caabcdafc1'),
#   'lastupdated': '2015-08-20 00:18:44.750000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaff8'),
#   'lastupdated': '2015-06-05 00:18:43.167000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9caa'),
#   'lastupdated': '2015-08-09 00:18:18.943000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9f01'),
#   'lastupdated': '2015-09-01 01:05:08.677000000'},
#  {'_id': ObjectId('573a1392f29313caabcda1d2'),
#   'lastupdated': '2015-08-25 00:03:51.417000000'},
#  {'_id': ObjectId('573a1392f29313caabcda556'),
#   'lastupdated': '2015-08-22 00:36:29.047000000'},
#  {'_id': ObjectId('573a1392f29313caabcda5b7'),
#   'lastupdated': '2015-05-23 00:02:26.143000000'},
#  {'_id': ObjectId('573a1392f29313caabcda7a4'),
#   'lastupdated': '2015-08-25 00:10:49.713000000'},
#  {'_id': ObjectId('573a1392f29313caabcdafdb'),
#   'lastupdated': '2015-08-24 00:25:35.620000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb11c'),
#   'lastupdated': '2015-08-21 00:02:54.437000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb148'),
#   'lastupdated': '2015-08-20 00:28:41.017000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9ca6'),
#   'lastupdated': '2015-09-03 00:32:16.227000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9eb0'),
#   'lastupdated': '2015-03-25 01:03:12.497000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9ee7'),
#   'lastupdated': '2015-08-26 01:04:37.273000000'},
#  {'_id': ObjectId('573a1392f29313caabcda3dc'),
#   'lastupdated': '2015-09-12 00:20:26.513000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb108'),
#   'lastupdated': '2015-08-30 00:50:22.150000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9f7e'),
#   'lastupdated': '2015-08-31 00:25:18.513000000'},
#  {'_id': ObjectId('573a1392f29313caabcda3e9'),
#   'lastupdated': '2015-08-20 00:41:33.923000000'},
#  {'_id': ObjectId('573a1392f29313caabcda64c'),
#   'lastupdated': '2015-08-09 00:53:58.710000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6f7'),
#   'lastupdated': '2015-09-05 00:25:24.923000000'},
#  {'_id': ObjectId('573a1392f29313caabcda78f'),
#   'lastupdated': '2015-09-15 00:47:26.063000000'},
#  {'_id': ObjectId('573a1392f29313caabcda7fb'),
#   'lastupdated': '2015-07-08 09:11:27.910000000'},
#  {'_id': ObjectId('573a1392f29313caabcda930'),
#   'lastupdated': '2015-09-02 00:28:56.930000000'},
#  {'_id': ObjectId('573a1392f29313caabcda959'),
#   'lastupdated': '2015-09-01 00:19:40.020000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaa3c'),
#   'lastupdated': '2015-07-11 00:28:22.637000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaa3e'),
#   'lastupdated': '2015-09-17 04:46:29.313000000'},
#  {'_id': ObjectId('573a1392f29313caabcdad95'),
#   'lastupdated': '2015-08-09 00:51:41.850000000'},
#  {'_id': ObjectId('573a1392f29313caabcdae5e'),
#   'lastupdated': '2015-08-10 00:13:48.767000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaee0'),
#   'lastupdated': '2015-08-22 00:11:44.407000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf34'),
#   'lastupdated': '2015-02-18 00:59:01.800000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9f00'),
#   'lastupdated': '2015-06-23 00:15:38.917000000'},
#  {'_id': ObjectId('573a1392f29313caabcda1e3'),
#   'lastupdated': '2015-07-22 00:20:40.843000000'},
#  {'_id': ObjectId('573a1392f29313caabcda477'),
#   'lastupdated': '2015-06-07 00:44:09.763000000'},
#  {'_id': ObjectId('573a1392f29313caabcda6a6'),
#   'lastupdated': '2015-09-15 05:02:28.550000000'},
#  {'_id': ObjectId('573a1392f29313caabcda70a'),
#   'lastupdated': '2015-09-17 04:41:44.297000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaa4a'),
#   'lastupdated': '2015-09-05 00:25:34.113000000'},
#  {'_id': ObjectId('573a1392f29313caabcdacf8'),
#   'lastupdated': '2015-08-22 01:00:57.923000000'},
#  {'_id': ObjectId('573a1392f29313caabcdad11'),
#   'lastupdated': '2015-09-17 04:44:12.740000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaf3a'),
#   'lastupdated': '2015-08-28 00:52:25.063000000'},
#  {'_id': ObjectId('573a1392f29313caabcdafa2'),
#   'lastupdated': '2015-08-29 00:55:42.187000000'},
#  {'_id': ObjectId('573a1392f29313caabcd9cfb'),
#   'lastupdated': '2015-09-01 00:05:45.413000000'},
#  {'_id': ObjectId('573a1392f29313caabcda094'),
#   'lastupdated': '2015-08-25 01:07:01.400000000'},
#  {'_id': ObjectId('573a1392f29313caabcda09b'),
#   'lastupdated': '2015-08-15 00:02:00.380000000'},
#  {'_id': ObjectId('573a1392f29313caabcda114'),
#   'lastupdated': '2015-09-17 04:38:53.390000000'},
#  {'_id': ObjectId('573a1392f29313caabcda391'),
#   'lastupdated': '2015-06-29 00:32:34.333000000'},
#  {'_id': ObjectId('573a1392f29313caabcda654'),
#   'lastupdated': '2015-08-20 00:24:08.127000000'},
#  {'_id': ObjectId('573a1392f29313caabcda781'),
#   'lastupdated': '2015-08-01 00:57:40.377000000'},
#  {'_id': ObjectId('573a1392f29313caabcdadf0'),
#   'lastupdated': '2015-08-09 00:23:35.600000000'},
#  {'_id': ObjectId('573a1392f29313caabcdaeca'),
#   'lastupdated': '2015-08-17 00:41:05.860000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb40b'),
#   'lastupdated': '2015-09-10 17:45:12.290000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb600'),
#   'lastupdated': '2015-08-26 00:24:58.057000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb6c0'),
#   'lastupdated': '2015-08-07 00:49:22.117000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb258'),
#   'lastupdated': '2015-09-17 04:42:12.493000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb3c7'),
#   'lastupdated': '2015-06-27 00:18:48.280000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb208'),
#   'lastupdated': '2015-09-11 00:08:11.383000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb505'),
#   'lastupdated': '2015-02-26 00:10:37.680000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbc89'),
#   'lastupdated': '2015-07-01 04:23:22.133000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe85'),
#   'lastupdated': '2015-08-16 00:09:43.180000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb5ef'),
#   'lastupdated': '2015-08-17 01:12:28.783000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe8f'),
#   'lastupdated': '2015-07-31 00:04:21.927000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb69f'),
#   'lastupdated': '2015-08-08 01:04:50.350000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc2e2'),
#   'lastupdated': '2015-09-16 07:39:42.720000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbe09'),
#   'lastupdated': '2014-08-15 00:10:09.037000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbed5'),
#   'lastupdated': '2015-09-12 00:17:59.070000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbf6c'),
#   'lastupdated': '2015-08-08 00:56:43.740000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc150'),
#   'lastupdated': '2015-08-24 00:44:24.947000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc4b3'),
#   'lastupdated': '2015-09-04 00:25:06.477000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc514'),
#   'lastupdated': '2015-09-02 00:24:08.023000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc544'),
#   'lastupdated': '2015-09-11 00:32:09.287000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb82c'),
#   'lastupdated': '2015-08-18 00:59:28.093000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb9a1'),
#   'lastupdated': '2015-09-14 00:01:05.313000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb9e8'),
#   'lastupdated': '2015-08-25 00:12:07.103000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbb8a'),
#   'lastupdated': '2015-08-31 00:25:47.763000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe46'),
#   'lastupdated': '2015-09-14 12:55:44.180000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbef6'),
#   'lastupdated': '2015-08-28 00:13:05.830000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbf81'),
#   'lastupdated': '2015-05-31 00:01:35.230000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc076'),
#   'lastupdated': '2015-08-19 00:30:45.750000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc0bb'),
#   'lastupdated': '2015-09-14 11:50:17.477000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc3f7'),
#   'lastupdated': '2015-09-02 00:25:14.257000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc5cb'),
#   'lastupdated': '2015-08-27 00:29:40.820000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb496'),
#   'lastupdated': '2015-09-02 00:23:49.430000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb58d'),
#   'lastupdated': '2015-09-17 04:38:34.737000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb5a9'),
#   'lastupdated': '2015-08-30 00:44:33.900000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb646'),
#   'lastupdated': '2015-08-14 00:04:00.287000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb700'),
#   'lastupdated': '2015-08-23 00:19:27.547000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbd07'),
#   'lastupdated': '2015-08-07 00:01:07.053000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbef1'),
#   'lastupdated': '2015-07-27 00:15:16.370000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc16f'),
#   'lastupdated': '2015-08-27 00:45:25.040000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc269'),
#   'lastupdated': '2015-08-22 00:36:25.407000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc403'),
#   'lastupdated': '2015-09-14 11:06:52.267000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc530'),
#   'lastupdated': '2015-08-26 01:10:05.430000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb571'),
#   'lastupdated': '2015-09-02 00:23:56.867000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb5cb'),
#   'lastupdated': '2015-08-24 00:45:14.900000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb770'),
#   'lastupdated': '2015-08-29 00:55:58.593000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb7b9'),
#   'lastupdated': '2015-06-06 00:53:57.643000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb7ef'),
#   'lastupdated': '2015-02-26 00:15:20.447000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe7c'),
#   'lastupdated': '2015-09-01 00:29:05.490000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbf82'),
#   'lastupdated': '2015-09-16 08:23:06.087000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc0a0'),
#   'lastupdated': '2015-09-16 08:23:16.023000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc23e'),
#   'lastupdated': '2015-09-17 04:24:29.313000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb4ee'),
#   'lastupdated': '2015-08-26 01:10:06.633000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb5fc'),
#   'lastupdated': '2015-09-04 00:07:37.240000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb82f'),
#   'lastupdated': '2015-09-17 04:42:41.213000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb8ac'),
#   'lastupdated': '2015-09-02 00:24:41.850000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb9eb'),
#   'lastupdated': '2015-02-15 00:31:43.463000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbc8d'),
#   'lastupdated': '2015-07-31 00:23:27.487000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc4b6'),
#   'lastupdated': '2015-07-26 00:19:14.303000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb20d'),
#   'lastupdated': '2015-08-21 00:20:15.390000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb29d'),
#   'lastupdated': '2015-08-23 00:55:18.423000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb27d'),
#   'lastupdated': '2015-08-10 01:01:59.283000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb585'),
#   'lastupdated': '2015-08-14 00:11:51.833000000'},
#  {'_id': ObjectId('573a1392f29313caabcdba01'),
#   'lastupdated': '2015-08-22 00:24:36.860000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbb86'),
#   'lastupdated': '2015-09-07 01:14:17.493000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbceb'),
#   'lastupdated': '2015-09-04 00:35:54.413000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbeca'),
#   'lastupdated': '2015-04-13 01:18:38.917000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbed0'),
#   'lastupdated': '2015-07-21 08:16:03.510000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc3a3'),
#   'lastupdated': '2015-08-31 00:18:44.123000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc4a2'),
#   'lastupdated': '2015-09-05 00:27:56.940000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb48b'),
#   'lastupdated': '2015-09-07 00:22:15.603000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb3aa'),
#   'lastupdated': '2015-09-14 07:55:54.790000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb2cd'),
#   'lastupdated': '2015-09-07 00:04:30.137000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb397'),
#   'lastupdated': '2015-07-24 00:53:01.413000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb774'),
#   'lastupdated': '2015-09-17 04:02:33.090000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb7b7'),
#   'lastupdated': '2015-09-05 00:26:51.410000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbad6'),
#   'lastupdated': '2015-09-06 00:22:11.213000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbb52'),
#   'lastupdated': '2015-09-14 09:47:13.690000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbbae'),
#   'lastupdated': '2015-09-05 00:27:06.487000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc030'),
#   'lastupdated': '2015-09-14 09:47:08.293000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc04b'),
#   'lastupdated': '2015-09-01 01:18:49.693000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc13b'),
#   'lastupdated': '2015-08-21 00:29:09.750000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc180'),
#   'lastupdated': '2015-09-10 17:47:32.900000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb30f'),
#   'lastupdated': '2015-08-22 00:36:27.233000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb618'),
#   'lastupdated': '2015-09-02 00:24:00.070000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb672'),
#   'lastupdated': '2015-07-28 00:59:35.120000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb94f'),
#   'lastupdated': '2015-07-25 00:04:48.757000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbcbc'),
#   'lastupdated': '2015-09-16 08:12:27.890000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbfcc'),
#   'lastupdated': '2015-09-15 05:02:01.577000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc364'),
#   'lastupdated': '2015-09-05 00:27:47.423000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc4a8'),
#   'lastupdated': '2015-09-14 12:55:39.293000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb314'),
#   'lastupdated': '2015-08-30 00:55:10.257000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb3f2'),
#   'lastupdated': '2015-09-04 00:06:37.897000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb659'),
#   'lastupdated': '2015-06-17 18:38:09.420000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb8b5'),
#   'lastupdated': '2015-08-09 00:08:32.180000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb9ff'),
#   'lastupdated': '2015-09-04 00:22:01.990000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbd80'),
#   'lastupdated': '2015-09-14 02:15:50.523000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc62b'),
#   'lastupdated': '2015-09-17 04:43:21.363000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb495'),
#   'lastupdated': '2015-09-03 00:51:55.490000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb4d5'),
#   'lastupdated': '2015-05-10 00:40:53.917000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb5ab'),
#   'lastupdated': '2015-08-23 01:11:59.613000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb7c1'),
#   'lastupdated': '2015-08-23 01:14:21.583000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbaef'),
#   'lastupdated': '2015-09-10 17:38:43.810000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc01a'),
#   'lastupdated': '2015-09-11 00:20:47.797000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc093'),
#   'lastupdated': '2015-08-24 00:22:43.290000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc435'),
#   'lastupdated': '2015-07-23 00:45:40.570000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb58c'),
#   'lastupdated': '2015-08-26 00:30:12.510000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb89c'),
#   'lastupdated': '2015-08-21 00:00:40.033000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb980'),
#   'lastupdated': '2015-09-17 04:44:36.710000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb9d4'),
#   'lastupdated': '2015-07-27 00:06:07.120000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbb45'),
#   'lastupdated': '2015-09-02 00:24:14.117000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbd65'),
#   'lastupdated': '2015-08-20 01:01:48.687000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc0f7'),
#   'lastupdated': '2015-09-04 00:07:34.773000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc207'),
#   'lastupdated': '2015-09-05 00:27:42.173000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc370'),
#   'lastupdated': '2015-04-09 01:08:27.730000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb295'),
#   'lastupdated': '2015-08-22 00:43:06.657000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb2c9'),
#   'lastupdated': '2015-08-13 00:22:59.630000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb28b'),
#   'lastupdated': '2015-04-17 01:58:23.863000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb82a'),
#   'lastupdated': '2015-08-17 00:13:27.640000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbc0f'),
#   'lastupdated': '2015-08-08 01:03:34.083000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbd59'),
#   'lastupdated': '2015-07-12 00:06:08.983000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbdd3'),
#   'lastupdated': '2015-09-02 00:42:27.583000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbfb0'),
#   'lastupdated': '2015-09-10 17:06:36.233000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc159'),
#   'lastupdated': '2015-09-05 00:27:33.580000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc371'),
#   'lastupdated': '2015-06-29 01:08:22.717000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc50e'),
#   'lastupdated': '2014-10-09 00:21:33.780000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc539'),
#   'lastupdated': '2015-06-27 00:33:20.233000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc57c'),
#   'lastupdated': '2015-05-22 10:56:19.617000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb2fb'),
#   'lastupdated': '2015-09-17 04:46:07.310000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb590'),
#   'lastupdated': '2015-08-21 00:21:41.640000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb61b'),
#   'lastupdated': '2015-07-23 00:23:21.147000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb73e'),
#   'lastupdated': '2015-08-21 00:09:43'},
#  {'_id': ObjectId('573a1392f29313caabcdb970'),
#   'lastupdated': '2015-08-05 00:14:14.180000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbde3'),
#   'lastupdated': '2015-08-25 00:23:01.947000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbe1c'),
#   'lastupdated': '2014-08-17 00:15:23.487000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe5b'),
#   'lastupdated': '2015-01-09 00:20:00.943000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe83'),
#   'lastupdated': '2015-09-02 00:21:10.757000000'},
#  {'_id': ObjectId('573a1393f29313caabcdbe87'),
#   'lastupdated': '2015-08-21 00:02:15.937000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc1c2'),
#   'lastupdated': '2015-09-17 01:24:04.527000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc444'),
#   'lastupdated': '2015-08-23 00:16:18.140000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc536'),
#   'lastupdated': '2015-09-15 04:50:25.603000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb3f4'),
#   'lastupdated': '2015-09-05 00:40:52.307000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb47e'),
#   'lastupdated': '2015-09-05 00:26:32.050000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb73c'),
#   'lastupdated': '2015-08-25 01:15:32.587000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbdce'),
#   'lastupdated': '2015-08-29 00:20:31.390000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbddf'),
#   'lastupdated': '2015-08-21 00:11:38.610000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc5dc'),
#   'lastupdated': '2015-08-07 00:48:49.523000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb231'),
#   'lastupdated': '2015-03-29 01:48:09.213000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb2dc'),
#   'lastupdated': '2015-08-23 00:07:26.077000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb497'),
#   'lastupdated': '2015-09-01 00:55:54.333000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb529'),
#   'lastupdated': '2015-08-28 00:39:03.503000000'},
#  {'_id': ObjectId('573a1392f29313caabcdb56d'),
#   'lastupdated': '2015-08-21 00:52:00.437000000'},
#  {'_id': ObjectId('573a1392f29313caabcdba09'),
#   'lastupdated': '2015-08-22 00:29:07.390000000'},
#  {'_id': ObjectId('573a1392f29313caabcdbabd'),
#   'lastupdated': '2015-09-01 01:09:53.663000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc0cb'),
#   'lastupdated': '2015-08-26 01:15:36.213000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc558'),
#   'lastupdated': '2015-09-07 00:35:55.783000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc939'),
#   'lastupdated': '2015-08-22 01:05:09.530000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc810'),
#   'lastupdated': '2015-09-04 00:22:54.600000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc6c6'),
#   'lastupdated': '2015-09-05 00:28:15.847000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc9ab'),
#   'lastupdated': '2015-08-20 00:05:57.033000000'},
#  {'_id': ObjectId('573a1393f29313caabcdcb60'),
#   'lastupdated': '2015-05-23 00:12:25.747000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc672'),
#   'lastupdated': '2015-08-25 00:01:49.650000000'},
#  {'_id': ObjectId('573a1393f29313caabcdc87b'),
#   'lastupdated': '2015-07-24 01:01:54.977000000'},
#  {'_id': ObjectId('573a1393f29313caabcdcaa1'),
#   'lastupdated': '2015-09-17 04:39:33.827000000'},
#  {'_id': ObjectId('573a1393f29313caabcdcbdd'),
#   'lastupdated': '2015-09-05 00:28:49.097000000'},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'lastupdated': '2015-08-16 00:16:16.823000000'},
#  {'_id': ObjectId('573a1393f29313caabcdceb0'),
#   'lastupdated': '2015-08-20 00:42:21.890000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd0e5'),
#   'lastupdated': '2015-09-17 01:24:38.307000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd1f5'),
#   'lastupdated': '2015-09-05 00:29:35.317000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd5e9'),
#   'lastupdated': '2015-08-19 00:11:25.860000000'},
# ...
#  {'_id': ObjectId('573a1393f29313caabcdda94'),
#   'lastupdated': '2015-08-09 01:29:06.393000000'},
#  {'_id': ObjectId('573a1393f29313caabcddd6a'),
#   'lastupdated': '2015-08-24 00:06:52.930000000'},
#  {'_id': ObjectId('573a1393f29313caabcdde51'),
#   'lastupdated': '2015-08-25 00:09:37.167000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf0e'),
#   'lastupdated': '2015-09-17 04:49:07.113000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf82'),
#   'lastupdated': '2015-09-07 01:09:58.743000000'},
#  {'_id': ObjectId('573a1393f29313caabcddfee'),
#   'lastupdated': '2015-09-04 00:27:05.083000000'},
#  {'_id': ObjectId('573a1393f29313caabcde089'),
#   'lastupdated': '2015-09-02 00:25:03.663000000'},
#  {'_id': ObjectId('573a1393f29313caabcde160'),
#   'lastupdated': '2015-09-02 00:20:29.037000000'},
#  {'_id': ObjectId('573a1393f29313caabcde3ef'),
#   'lastupdated': '2015-05-16 00:08:48.200000000'},
#  {'_id': ObjectId('573a1394f29313caabcde5b4'),
#   'lastupdated': '2015-08-21 00:35:43.220000000'},
#  {'_id': ObjectId('573a1394f29313caabcde77f'),
#   'lastupdated': '2015-08-21 00:49:49.250000000'},
#  {'_id': ObjectId('573a1394f29313caabcde7ee'),
#   'lastupdated': '2015-09-17 04:39:05.470000000'},
#  {'_id': ObjectId('573a1394f29313caabcde822'),
#   'lastupdated': '2015-09-05 00:01:23.533000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea4e'),
#   'lastupdated': '2015-08-04 00:38:01.630000000'},
#  {'_id': ObjectId('573a1394f29313caabcdec01'),
#   'lastupdated': '2015-09-05 00:33:18.630000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeca3'),
#   'lastupdated': '2015-08-29 00:07:39.780000000'},
#  {'_id': ObjectId('573a1394f29313caabcded1c'),
#   'lastupdated': '2015-08-23 00:44:00.827000000'},
#  {'_id': ObjectId('573a1394f29313caabcded2e'),
#   'lastupdated': '2015-08-19 00:00:33.733000000'},
#  {'_id': ObjectId('573a1394f29313caabcdef0c'),
#   'lastupdated': '2015-08-17 01:08:56.283000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd8c7'),
#   'lastupdated': '2015-09-15 05:02:27.580000000'},
#  {'_id': ObjectId('573a1393f29313caabcddad5'),
#   'lastupdated': '2015-09-12 00:35:34.840000000'},
#  {'_id': ObjectId('573a1393f29313caabcddaf1'),
#   'lastupdated': '2015-08-07 00:47:16.193000000'},
#  {'_id': ObjectId('573a1393f29313caabcddb29'),
#   'lastupdated': '2015-07-31 00:07:58.177000000'},
#  {'_id': ObjectId('573a1393f29313caabcdde70'),
#   'lastupdated': '2015-09-07 00:46:18.713000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf1e'),
#   'lastupdated': '2015-08-25 00:41:25.540000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf4d'),
#   'lastupdated': '2015-08-21 00:07:09.813000000'},
#  {'_id': ObjectId('573a1393f29313caabcddfa4'),
#   'lastupdated': '2015-08-04 01:01:38.430000000'},
#  {'_id': ObjectId('573a1393f29313caabcddfcf'),
#   'lastupdated': '2015-08-21 00:11:40.140000000'},
#  {'_id': ObjectId('573a1393f29313caabcde01b'),
#   'lastupdated': '2015-08-15 00:20:47.600000000'},
#  {'_id': ObjectId('573a1393f29313caabcde043'),
#   'lastupdated': '2015-07-27 00:10:00.637000000'},
#  {'_id': ObjectId('573a1393f29313caabcde2c4'),
#   'lastupdated': '2015-05-10 00:16:59.860000000'},
#  {'_id': ObjectId('573a1393f29313caabcde300'),
#   'lastupdated': '2015-08-12 00:53:53.767000000'},
#  {'_id': ObjectId('573a1393f29313caabcde367'),
#   'lastupdated': '2015-07-26 00:43:43.257000000'},
#  {'_id': ObjectId('573a1393f29313caabcde398'),
#   'lastupdated': '2015-05-14 00:35:57.377000000'},
#  {'_id': ObjectId('573a1393f29313caabcde3af'),
#   'lastupdated': '2015-08-26 01:17:07.773000000'},
#  {'_id': ObjectId('573a1393f29313caabcde40d'),
#   'lastupdated': '2015-09-05 00:27:01.567000000'},
#  {'_id': ObjectId('573a1393f29313caabcde417'),
#   'lastupdated': '2015-08-12 00:51:11.610000000'},
#  {'_id': ObjectId('573a1394f29313caabcde875'),
#   'lastupdated': '2015-08-31 00:46:03.763000000'},
#  {'_id': ObjectId('573a1394f29313caabcde9db'),
#   'lastupdated': '2015-09-15 02:23:05.967000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea0a'),
#   'lastupdated': '2015-09-05 00:32:42.677000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea1e'),
#   'lastupdated': '2015-08-15 00:18:15.817000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea8e'),
#   'lastupdated': '2015-08-22 00:36:21.233000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeada'),
#   'lastupdated': '2015-08-21 00:05:12.063000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeb3d'),
#   'lastupdated': '2015-09-07 00:44:59.093000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeb7e'),
#   'lastupdated': '2015-08-21 00:11:04.470000000'},
#  {'_id': ObjectId('573a1394f29313caabcdec5e'),
#   'lastupdated': '2015-09-11 00:46:10.807000000'},
#  {'_id': ObjectId('573a1394f29313caabcdee99'),
#   'lastupdated': '2015-09-07 00:10:22.953000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeec2'),
#   'lastupdated': '2015-09-02 00:41:27.210000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf043'),
#   'lastupdated': '2015-08-24 00:57:11.667000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf05c'),
#   'lastupdated': '2015-08-26 00:09:40.167000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd807'),
#   'lastupdated': '2015-08-20 00:42:28.970000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd9c7'),
#   'lastupdated': '2015-05-02 00:59:33.213000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd9fe'),
#   'lastupdated': '2015-09-01 00:33:28.647000000'},
#  {'_id': ObjectId('573a1393f29313caabcddae1'),
#   'lastupdated': '2015-08-17 01:04:11.080000000'},
#  {'_id': ObjectId('573a1393f29313caabcdded2'),
#   'lastupdated': '2015-08-07 00:02:12.850000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf88'),
#   'lastupdated': '2015-03-24 02:03:04.180000000'},
#  {'_id': ObjectId('573a1393f29313caabcde022'),
#   'lastupdated': '2015-05-21 00:25:58.703000000'},
#  {'_id': ObjectId('573a1393f29313caabcde2db'),
#   'lastupdated': '2015-02-19 00:58:02.427000000'},
#  {'_id': ObjectId('573a1393f29313caabcde361'),
#   'lastupdated': '2015-08-27 00:52:39.430000000'},
#  {'_id': ObjectId('573a1393f29313caabcde3be'),
#   'lastupdated': '2015-09-07 00:23:31.577000000'},
#  {'_id': ObjectId('573a1393f29313caabcde3ee'),
#   'lastupdated': '2015-09-01 01:19:48.287000000'},
#  {'_id': ObjectId('573a1393f29313caabcde515'),
#   'lastupdated': '2015-09-02 00:25:19.367000000'},
#  {'_id': ObjectId('573a1394f29313caabcde788'),
#   'lastupdated': '2015-08-21 00:15:29.580000000'},
#  {'_id': ObjectId('573a1394f29313caabcde82b'),
#   'lastupdated': '2015-09-17 04:39:41.120000000'},
#  {'_id': ObjectId('573a1394f29313caabcde91f'),
#   'lastupdated': '2015-08-14 01:08:33.443000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeb43'),
#   'lastupdated': '2015-09-15 02:51:45.650000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeb7d'),
#   'lastupdated': '2015-09-05 00:33:10.757000000'},
#  {'_id': ObjectId('573a1394f29313caabcdec81'),
#   'lastupdated': '2015-08-17 00:47:50.033000000'},
#  {'_id': ObjectId('573a1394f29313caabcdecb5'),
#   'lastupdated': '2015-08-17 00:40:09.593000000'},
#  {'_id': ObjectId('573a1394f29313caabcdef7f'),
#   'lastupdated': '2015-08-14 00:31:47.223000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd859'),
#   'lastupdated': '2015-08-23 00:01:53.593000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbe4'),
#   'lastupdated': '2015-09-14 23:47:32.363000000'},
#  {'_id': ObjectId('573a1393f29313caabcddd6d'),
#   'lastupdated': '2015-08-22 00:47:18.313000000'},
#  {'_id': ObjectId('573a1393f29313caabcddd8f'),
#   'lastupdated': '2015-07-25 00:41:46.727000000'},
#  {'_id': ObjectId('573a1393f29313caabcddde7'),
#   'lastupdated': '2015-09-02 00:27:25.897000000'},
#  {'_id': ObjectId('573a1393f29313caabcdde5a'),
#   'lastupdated': '2015-09-17 04:44:23.147000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf27'),
#   'lastupdated': '2015-09-14 07:21:29.090000000'},
#  {'_id': ObjectId('573a1393f29313caabcde2fc'),
#   'lastupdated': '2015-08-11 00:02:07.967000000'},
#  {'_id': ObjectId('573a1393f29313caabcde36c'),
#   'lastupdated': '2015-09-17 04:52:06.653000000'},
#  {'_id': ObjectId('573a1394f29313caabcde5f5'),
#   'lastupdated': '2015-07-15 00:28:53.833000000'},
#  {'_id': ObjectId('573a1394f29313caabcde613'),
#   'lastupdated': '2015-02-16 00:32:27.973000000'},
#  {'_id': ObjectId('573a1394f29313caabcde681'),
#   'lastupdated': '2015-07-25 00:20:51.773000000'},
#  {'_id': ObjectId('573a1394f29313caabcde95b'),
#   'lastupdated': '2015-08-20 00:08:46.483000000'},
#  {'_id': ObjectId('573a1394f29313caabcde9ef'),
#   'lastupdated': '2015-09-05 00:02:42.143000000'},
#  {'_id': ObjectId('573a1394f29313caabcdebfc'),
#   'lastupdated': '2015-07-29 00:21:22.223000000'},
#  {'_id': ObjectId('573a1394f29313caabcdecc3'),
#   'lastupdated': '2015-09-17 04:40:41.703000000'},
#  {'_id': ObjectId('573a1394f29313caabcded50'),
#   'lastupdated': '2015-09-06 00:17:20.073000000'},
#  {'_id': ObjectId('573a1394f29313caabcdedf8'),
#   'lastupdated': '2015-08-28 00:07:46.813000000'},
#  {'_id': ObjectId('573a1394f29313caabcdef53'),
#   'lastupdated': '2015-08-22 00:43:56.110000000'},
#  {'_id': ObjectId('573a1394f29313caabcdefaa'),
#   'lastupdated': '2015-09-04 00:18:55.163000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd8f4'),
#   'lastupdated': '2015-09-17 03:38:06.987000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbb8'),
#   'lastupdated': '2015-08-14 00:29:23.270000000'},
#  {'_id': ObjectId('573a1393f29313caabcdddb8'),
#   'lastupdated': '2015-08-20 00:20:43.687000000'},
#  {'_id': ObjectId('573a1393f29313caabcdde6d'),
#   'lastupdated': '2015-09-06 00:57:38.620000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf1b'),
#   'lastupdated': '2015-09-15 04:00:17.560000000'},
#  {'_id': ObjectId('573a1393f29313caabcddfd3'),
#   'lastupdated': '2015-08-24 00:57:01.807000000'},
#  {'_id': ObjectId('573a1393f29313caabcddff4'),
#   'lastupdated': '2015-08-21 00:41:07.127000000'},
#  {'_id': ObjectId('573a1393f29313caabcde024'),
#   'lastupdated': '2015-09-17 04:49:16.180000000'},
#  {'_id': ObjectId('573a1393f29313caabcde083'),
#   'lastupdated': '2015-09-02 00:41:07.820000000'},
#  {'_id': ObjectId('573a1394f29313caabcde631'),
#   'lastupdated': '2015-09-15 04:49:13.510000000'},
#  {'_id': ObjectId('573a1394f29313caabcde6d3'),
#   'lastupdated': '2015-08-25 00:12:44.523000000'},
#  {'_id': ObjectId('573a1394f29313caabcde7b1'),
#   'lastupdated': '2015-09-16 08:12:32.657000000'},
#  {'_id': ObjectId('573a1394f29313caabcde7b3'),
#   'lastupdated': '2015-02-24 00:32:40.987000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea3a'),
#   'lastupdated': '2015-04-13 00:31:48.683000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea4b'),
#   'lastupdated': '2015-08-11 00:30:53.657000000'},
#  {'_id': ObjectId('573a1394f29313caabcdebf9'),
#   'lastupdated': '2015-09-15 03:47:34.420000000'},
#  {'_id': ObjectId('573a1394f29313caabcdec96'),
#   'lastupdated': '2015-08-09 01:29:36.363000000'},
#  {'_id': ObjectId('573a1394f29313caabcdecfb'),
#   'lastupdated': '2015-09-07 00:56:54.787000000'},
#  {'_id': ObjectId('573a1394f29313caabcdeeb7'),
#   'lastupdated': '2015-07-03 00:22:37.020000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf03b'),
#   'lastupdated': '2015-08-03 00:25:33.333000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd7ed'),
#   'lastupdated': '2015-08-22 00:49:29.157000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd831'),
#   'lastupdated': '2015-09-01 00:32:26.960000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd8ad'),
#   'lastupdated': '2014-09-23 00:18:53.727000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbb0'),
#   'lastupdated': '2015-08-08 00:57:27.523000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbb7'),
#   'lastupdated': '2015-09-16 12:22:10.340000000'},
#  {'_id': ObjectId('573a1393f29313caabcddd8a'),
#   'lastupdated': '2015-05-24 00:45:43.773000000'},
#  {'_id': ObjectId('573a1393f29313caabcddfbd'),
#   'lastupdated': '2015-08-10 00:39:14.300000000'},
#  {'_id': ObjectId('573a1393f29313caabcde008'),
#   'lastupdated': '2015-09-06 00:54:06.103000000'},
#  {'_id': ObjectId('573a1393f29313caabcde07e'),
#   'lastupdated': '2015-08-09 01:11:10.003000000'},
#  {'_id': ObjectId('573a1393f29313caabcde0e7'),
#   'lastupdated': '2015-07-04 00:11:58.537000000'},
#  {'_id': ObjectId('573a1393f29313caabcde0f0'),
#   'lastupdated': '2015-09-01 01:00:04.333000000'},
#  {'_id': ObjectId('573a1393f29313caabcde107'),
#   'lastupdated': '2015-04-14 00:13:05.590000000'},
#  {'_id': ObjectId('573a1393f29313caabcde1f8'),
#   'lastupdated': '2015-08-25 00:56:38.993000000'},
#  {'_id': ObjectId('573a1393f29313caabcde3dc'),
#   'lastupdated': '2015-08-21 00:05:09.983000000'},
#  {'_id': ObjectId('573a1394f29313caabcde678'),
#   'lastupdated': '2015-09-04 00:38:03.007000000'},
#  {'_id': ObjectId('573a1394f29313caabcde75e'),
#   'lastupdated': '2015-09-11 00:00:09.257000000'},
#  {'_id': ObjectId('573a1394f29313caabcde95f'),
#   'lastupdated': '2015-05-13 00:47:03.683000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea6d'),
#   'lastupdated': '2015-04-07 00:46:45.923000000'},
#  {'_id': ObjectId('573a1394f29313caabcdee8e'),
#   'lastupdated': '2015-08-04 00:39:47.303000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf01e'),
#   'lastupdated': '2015-09-05 00:33:51.297000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf03f'),
#   'lastupdated': '2015-08-21 00:56:07.673000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd840'),
#   'lastupdated': '2015-09-05 00:01:24.457000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd8af'),
#   'lastupdated': '2015-04-15 00:55:28.787000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd901'),
#   'lastupdated': '2015-09-05 00:30:45.347000000'},
#  {'_id': ObjectId('573a1393f29313caabcdd9b4'),
#   'lastupdated': '2015-08-22 01:12:24.843000000'},
#  {'_id': ObjectId('573a1393f29313caabcddaf2'),
#   'lastupdated': '2015-05-19 01:40:52.957000000'},
#  {'_id': ObjectId('573a1393f29313caabcddb2b'),
#   'lastupdated': '2015-08-05 00:29:18.990000000'},
#  {'_id': ObjectId('573a1393f29313caabcddba9'),
#   'lastupdated': '2015-08-24 00:25:15.680000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbb5'),
#   'lastupdated': '2015-09-07 01:15:30.913000000'},
#  {'_id': ObjectId('573a1393f29313caabcddbed'),
#   'lastupdated': '2014-01-23 00:00:00'},
#  {'_id': ObjectId('573a1393f29313caabcddc55'),
#   'lastupdated': '2015-09-07 08:33:44.247000000'},
#  {'_id': ObjectId('573a1393f29313caabcddc76'),
#   'lastupdated': '2015-03-28 00:59:45.237000000'},
#  {'_id': ObjectId('573a1393f29313caabcddd7d'),
#   'lastupdated': '2015-07-30 00:13:16.787000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf56'),
#   'lastupdated': '2015-08-31 00:52:47.607000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf5e'),
#   'lastupdated': '2015-08-25 00:57:23.900000000'},
#  {'_id': ObjectId('573a1393f29313caabcddf76'),
#   'lastupdated': '2015-09-01 01:02:44.693000000'},
#  {'_id': ObjectId('573a1393f29313caabcde1dd'),
#   'lastupdated': '2015-09-16 03:42:42.353000000'},
#  {'_id': ObjectId('573a1393f29313caabcde214'),
#   'lastupdated': '2015-08-19 00:13:29.767000000'},
#  {'_id': ObjectId('573a1393f29313caabcde309'),
#   'lastupdated': '2015-03-20 01:23:54.430000000'},
#  {'_id': ObjectId('573a1393f29313caabcde326'),
#   'lastupdated': '2015-08-14 00:52:16.537000000'},
#  {'_id': ObjectId('573a1393f29313caabcde453'),
#   'lastupdated': '2015-09-17 04:41:18.333000000'},
#  {'_id': ObjectId('573a1394f29313caabcde6fe'),
#   'lastupdated': '2015-09-12 00:24:26.450000000'},
#  {'_id': ObjectId('573a1394f29313caabcde70b'),
#   'lastupdated': '2015-05-06 03:27:53.713000000'},
#  {'_id': ObjectId('573a1394f29313caabcde7f9'),
#   'lastupdated': '2015-09-02 00:21:57.507000000'},
#  {'_id': ObjectId('573a1394f29313caabcde8e8'),
#   'lastupdated': '2015-08-06 00:49:05.443000000'},
#  {'_id': ObjectId('573a1394f29313caabcdea96'),
#   'lastupdated': '2015-08-01 00:11:32.610000000'},
#  {'_id': ObjectId('573a1394f29313caabcdec53'),
#   'lastupdated': '2015-08-31 00:33:39.543000000'},
#  {'_id': ObjectId('573a1394f29313caabcded1a'),
#   'lastupdated': '2015-09-15 03:58:00.553000000'},
#  {'_id': ObjectId('573a1394f29313caabcded2c'),
#   'lastupdated': '2015-09-16 13:00:57.300000000'},
#  {'_id': ObjectId('573a1394f29313caabcded8e'),
#   'lastupdated': '2015-08-05 01:11:30.430000000'},
#  {'_id': ObjectId('573a1394f29313caabcdee8d'),
#   'lastupdated': '2015-08-13 00:03:22.287000000'},
#  {'_id': ObjectId('573a1394f29313caabcdefa5'),
#   'lastupdated': '2015-09-11 00:31:50.937000000'},
#  {'_id': ObjectId('573a1394f29313caabcdf016'),
#   'lastupdated': '2015-09-14 09:47:11.813000000'},
#  ...]
